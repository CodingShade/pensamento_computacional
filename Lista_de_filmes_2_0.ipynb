# %%
def cadastrar_filme(filmes, notas):
    nome = input("Digite o nome do filme: ").strip()

    # Verifica se o filme já foi cadastrado
    if nome.lower() in (f.lower() for f in filmes):
        print("Este filme já foi cadastrado.")
        return filmes, notas

    while True:
        try:
            nota = float(input(f"Digite a nota para '{nome}' (0.0 a 10.0): "))
            if 0.0 <= nota <= 10.0:
                break
            else:
                print("A nota deve estar entre 0.0 e 10.0.")
        except ValueError:
            print("Por favor, digite uma nota válida (ex: 8.5).")

    filmes.append(nome)
    notas.append(nota)
    print(f"Filme '{nome}' adicionado com sucesso!")
    return filmes, notas

def editar_nota(filmes, notas):
    nome = input("Digite o nome do filme para editar a nota: ").strip()

    if nome not in filmes:
        print("Filme não encontrado.")
        return filmes, notas

    indice = filmes.index(nome)
    while True:
        try:
            nova_nota = float(input(f"Digite a nova nota para '{nome}' (0.0 a 10.0): "))
            if 0.0 <= nova_nota <= 10.0:
                notas[indice] = nova_nota
                print(f"A nota do filme '{nome}' foi atualizada para {nova_nota}.")
                break
            else:
                print("A nota deve estar entre 0.0 e 10.0.")
        except ValueError:
            print("Por favor, digite uma nota válida (ex: 8.5).")

    return filmes, notas

def remover_filme(filmes, notas):
    nome = input("Digite o nome do filme para remover: ").strip()

    if nome not in filmes:
        print("Filme não encontrado.")
        return filmes, notas

    indice = filmes.index(nome)
    filmes.pop(indice)
    notas.pop(indice)
    print(f"Filme '{nome}' removido com sucesso!")
    return filmes, notas

def mostrar_filmes(filmes, notas):
    print("\n--- Filmes Cadastrados ---")
    if len(filmes) == 0:
        print("Nenhum filme cadastrado.")
    else:
        for i in range(len(filmes)):
            print(f"{filmes[i]} — Nota: {notas[i]}")

def calcular_media(notas):
    if len(notas) == 0:
        return 0.0
    return sum(notas) / len(notas)

def exibir_menu():
    print("\n--- Menu ---")
    print("1. Adicionar Filme")
    print("2. Editar Nota de Filme")
    print("3. Remover Filme")
    print("4. Mostrar Filmes Cadastrados")
    print("5. Calcular Média das Notas")
    print("6. Sair")

def main():
    filmes = []
    notas = []

    while True:
        exibir_menu()
        opcao = input("Escolha uma opção (1-6): ").strip()

        if opcao == '1':
            filmes, notas = cadastrar_filme(filmes, notas)
        elif opcao == '2':
            filmes, notas = editar_nota(filmes, notas)
        elif opcao == '3':
            filmes, notas = remover_filme(filmes, notas)
        elif opcao == '4':
            mostrar_filmes(filmes, notas)
        elif opcao == '5':
            media = calcular_media(notas)
            print(f"\nNota média dos filmes: {media:.2f}")
        elif opcao == '6':
            print("Saindo...")
            break
        else:
            print("Opção inválida. Tente novamente.")

if __name__ == "__main__":
    main()
# Out:
# --- Menu ---
# 1. Adicionar Filme
# 2. Editar Nota de Filme
# 3. Remover Filme
# 4. Mostrar Filmes Cadastrados
# 5. Calcular Média das Notas
# 6. Sair
# Escolha uma opção (1-6): 5
#
# Nota média dos filmes: 0.00
#
# --- Menu ---
# 1. Adicionar Filme
# 2. Editar Nota de Filme
# 3. Remover Filme
# 4. Mostrar Filmes Cadastrados
# 5. Calcular Média das Notas
# 6. Sair
# Escolha uma opção (1-6): 1
# Digite o nome do filme: Avatar
# Digite a nota para 'Avatar' (0.0 a 10.0): 10
# Filme 'Avatar' adicionado com sucesso!
#
# --- Menu ---
# 1. Adicionar Filme
# 2. Editar Nota de Filme
# 3. Remover Filme
# 4. Mostrar Filmes Cadastrados
# 5. Calcular Média das Notas
# 6. Sair
# Escolha uma opção (1-6): 4
#
# --- Filmes Cadastrados ---
# Avatar — Nota: 10.0
#
# --- Menu ---
# 1. Adicionar Filme
# 2. Editar Nota de Filme
# 3. Remover Filme
# 4. Mostrar Filmes Cadastrados
# 5. Calcular Média das Notas
# 6. Sair
# Escolha uma opção (1-6): 1
# Digite o nome do filme: matrix
# Digite a nota para 'matrix' (0.0 a 10.0): 5
# Filme 'matrix' adicionado com sucesso!
#
# --- Menu ---
# 1. Adicionar Filme
# 2. Editar Nota de Filme
# 3. Remover Filme
# 4. Mostrar Filmes Cadastrados
# 5. Calcular Média das Notas
# 6. Sair
# Escolha uma opção (1-6): 4
#
# --- Filmes Cadastrados ---
# Avatar — Nota: 10.0
# matrix — Nota: 5.0
#
# --- Menu ---
# 1. Adicionar Filme
# 2. Editar Nota de Filme
# 3. Remover Filme
# 4. Mostrar Filmes Cadastrados
# 5. Calcular Média das Notas
# 6. Sair
# Escolha uma opção (1-6): 2
# Digite o nome do filme para editar a nota: Avatar
# Digite a nova nota para 'Avatar' (0.0 a 10.0): 7
# A nota do filme 'Avatar' foi atualizada para 7.0.
#
# --- Menu ---
# 1. Adicionar Filme
# 2. Editar Nota de Filme
# 3. Remover Filme
# 4. Mostrar Filmes Cadastrados
# 5. Calcular Média das Notas
# 6. Sair
# Escolha uma opção (1-6): 4
#
# --- Filmes Cadastrados ---
# Avatar — Nota: 7.0
# matrix — Nota: 5.0
#
# --- Menu ---
# 1. Adicionar Filme
# 2. Editar Nota de Filme
# 3. Remover Filme
# 4. Mostrar Filmes Cadastrados
# 5. Calcular Média das Notas
# 6. Sair
# Escolha uma opção (1-6): 6
# Saindo...
